# %%
import csv
import pandas as pd

# 27개 그룹 전체 데이터를 input, output, source 형식으로 정리
data = [
    # 1. Relative abundances of archaeal amplicon sequence variants (ASV)
    ["Relative abundances of archaeal amplicon sequence variants (ASV) from Canadian Prairie groundwater ecosystems",
     "Nucleotide sequences of archaeal amplicon sequence variants (ASV) from Canadian Prairie groundwater ecosystems", "데이터온"],
    ["Relative abundances of archaeal amplicon sequence variants (ASV) from Canadian Prairie groundwater ecosystems",
     "From Recharge, to Groundwater, to Discharge Areas in Aquifer Systems in Quebec (Canada): Shaping of Microbial Diversity and Community Structure by Environmental Factors", "사이언스온"],
    ["Relative abundances of archaeal amplicon sequence variants (ASV) from Canadian Prairie groundwater ecosystems",
     "Hydrogen and dark oxygen drive microbial productivity in diverse groundwater ecosystems", "사이언스온"],
    ["Relative abundances of archaeal amplicon sequence variants (ASV) from Canadian Prairie groundwater ecosystems",
     "Linking Groundwater to Surface Discharge Ecosystems: Archaeal, Bacterial, and Eukaryotic Community Diversity and Structure in Quebec (Canada)", "사이언스온"],
    ["Relative abundances of archaeal amplicon sequence variants (ASV) from Canadian Prairie groundwater ecosystems",
     "Energy efficiency and biological interactions define the core microbiome of deep oligotrophic groundwater", "사이언스온"],
    ["Relative abundances of archaeal amplicon sequence variants (ASV) from Canadian Prairie groundwater ecosystems",
     "Microbial biogeography of the eastern Yucatán carbonate aquifer", "사이언스온"],
    ["Relative abundances of archaeal amplicon sequence variants (ASV) from Canadian Prairie groundwater ecosystems",
     "Balancing Act: Groundwater microbiome’s resilience and vulnerability to hydroclimatic extremes", "사이언스온"],
    ["Relative abundances of archaeal amplicon sequence variants (ASV) from Canadian Prairie groundwater ecosystems",
     "Relative abundances of bacterial amplicon sequence variants (ASV) from Canadian Prairie groundwater ecosystems", "데이터온"],

    # 2. Proteomic Profiling of Seminal Plasma Proteins
    ["Proteomic Profiling of Seminal Plasma Proteins in Varicocele Patients",
     "Proteomic data of seminal plasma and spermatozoa of four purebred dogs", "데이터온"],
    ["Proteomic Profiling of Seminal Plasma Proteins in Varicocele Patients",
     "Proteomic Profiling of Seminal Plasma Proteins in Varicocele Patients", "사이언스온"],
    ["Proteomic Profiling of Seminal Plasma Proteins in Varicocele Patients",
     "Protein Fingerprinting of Seminal Plasma Reveals Dysregulation of Exosome-Associated Proteins in Infertile Men with Unilateral Varicocele", "사이언스온"],
    ["Proteomic Profiling of Seminal Plasma Proteins in Varicocele Patients",
     "PD36-09 DIFFERENTIAL EXPRESSION OF SEMINAL PLASMA PROTEINS IN RESPONDERS AND NON-RESPONDERS TO VARICOCELE TREATMENT", "사이언스온"],
    ["Proteomic Profiling of Seminal Plasma Proteins in Varicocele Patients",
     "Proteomics and Metabolomics in Varicocele-Associated Male Infertility: Advancing Precision Diagnostics and Therapy", "사이언스온"],
    ["Proteomic Profiling of Seminal Plasma Proteins in Varicocele Patients",
     "Molecular pathways of varicocele and its repair – A paired labelled shotgun proteomics approach (Camargo et al., Journal of Proteomics, 2019)", "사이언스온"],
    ["Proteomic Profiling of Seminal Plasma Proteins in Varicocele Patients",
     "Seminal Plasma Proteomic Biomarkers of Oxidative Stress (Cannarella et al., Int J Mol Sci, 2020)", "사이언스온"],
    ["Proteomic Profiling of Seminal Plasma Proteins in Varicocele Patients",
     "Changes in the seminal plasma proteome of adolescents before and after varicocelectomy (Del Giudice et al., Fertility and Sterility, 2013)", "사이언스온"],

    # 3. Supporting Information( Immunogenicity study of CSBV structural proteins)
    ["Supporting Information(Immunogenicity study of CSBV structural proteins)",
     "Analysis of MicroRNAs in Apis cerana larvae in Response to Chinese Sacbrood Virus (CSBV) Infection", "데이터온"],
    ["Supporting Information(Immunogenicity study of CSBV structural proteins)",
     "Codon Optimization, Expression in Escherichia coli , and Immunogenicity of Recombinant Chinese Sacbrood Virus (CSBV) Structural Proteins VP1, VP2, and VP3", "사이언스온"],
    ["Supporting Information(Immunogenicity study of CSBV structural proteins)",
     "Molecular and Biological Characterization of Chinese Sacbrood Virus LN Isolate", "사이언스온"],
    ["Supporting Information(Immunogenicity study of CSBV structural proteins)",
     "Proteomic Analysis of Apis cerana and Apis mellifera Larvae Fed with Heterospecific Royal Jelly and by CSBV Challenge", "사이언스온"],
    ["Supporting Information(Immunogenicity study of CSBV structural proteins)",
     "Correction: Codon Optimization, Expression in Escherichia coli, and Immunogenicity of Recombinant Chinese Sacbrood Virus (CSBV) Structural Proteins VP1, VP2, and VP3 – Fei, Dongliang 외, PloS One, 2015", "사이언스온"],
    ["Supporting Information(Immunogenicity study of CSBV structural proteins)",
     "Purification of Chinese Sacbrood Virus (CSBV), Gene Cloning and Prokaryotic Expression of its Structural Protein VP1 – Wu, Pengjie 외, Molecular Biotechnology, 2018", "사이언스온"],

    # 4. HADDOCK models of mutant protein complexes
    ["HADDOCK models of mutant protein complexes",
     "Dataset associated with 'An in-frame deletion mutation in the degron tail of auxin co-receptor IAA2 confers resistance to the herbicide 2,4-D in Sisymbrium orientale'", "데이터온"],
    ["HADDOCK models of mutant protein complexes",
     "S239D/I332E 변이 항체 Fc와 FcγRIIIa 수용체의 결합 구조에 대한 전산학적 연구 (In Silico Structural Study on the Binding of Antibody IgG Fc-S239D/I332E variant and FcγRIIIa Receptor)", "사이언스온"],
    ["HADDOCK models of mutant protein complexes",
     "LRET-derived HADDOCK structural models describe the conformational heterogeneity required for processivity of the Mre11-Rad50 DNA damage repair complex", "사이언스온"],
    ["HADDOCK models of mutant protein complexes",
     "Modeling Antibody-Antigen Complexes by Information-Driven Docking", "사이언스온"],
    ["HADDOCK models of mutant protein complexes",
     "Exploring the Binding Interaction of Raf Kinase Inhibitory Protein With the N-Terminal of C-Raf Through Molecular Docking and Molecular Dynamics Simulation", "사이언스온"],
    ["HADDOCK models of mutant protein complexes",
     "Predicting nsSNPs that Disrupt Protein-Protein Interactions Using Docking", "사이언스온"],
    ["HADDOCK models of mutant protein complexes",
     "Blocking the interface region amongst S100A6 and RAGE V domain via S100B protein", "사이언스온"],

    # 5. Tumor-Educated Immune Cells Promote Metastatic Growth
    ["Tumor-Educated Immune Cells Promote Metastatic Growth",
     "Dataset supporting Targeting tumor-intrinsic BCL9 reverses the resistance to immunotherapy by eliciting macrophage-mediated phagocytosis and antigen presentation", "데이터온"],
    ["Tumor-Educated Immune Cells Promote Metastatic Growth",
     "Tumor-educated Tregs drive organ-specific metastasis in breast cancer by impairing NK cells in the lymph node niche", "사이언스온"],
    ["Tumor-Educated Immune Cells Promote Metastatic Growth",
     "Tumor-educated mesenchymal stem cells promote pro-metastatic phenotype", "사이언스온"],
    ["Tumor-Educated Immune Cells Promote Metastatic Growth",
     "Tumor Extracellular Vesicles Regulate Macrophage-Driven Metastasis through CCL5", "사이언스온"],
    ["Tumor-Educated Immune Cells Promote Metastatic Growth",
     "Immune interconnectivity of anatomically distant tumors as a potential mediator of systemic responses to local therapy", "사이언스온"],
    ["Tumor-Educated Immune Cells Promote Metastatic Growth",
     "Immunosuppressive and Prometastatic Functions of Myeloid-Derived Suppressive Cells Rely upon Education from Tumor-Associated B Cells", "사이언스온"],
    ["Tumor-Educated Immune Cells Promote Metastatic Growth",
     "4PD Functionalized Dendrimers: A Flexible Tool for In Vivo Gene Silencing of Tumor-Educated Myeloid Cells", "사이언스온"],

    # 6. Moonwalker Descending Neurons (MDN)
    ["Moonwalker Descending Neurons (MDN)",
     "dorsal Moonwalker Ascending Neurons (dMAN)", "데이터온"],
    ["Moonwalker Descending Neurons (MDN)",
     "Moonwalker Descending Neurons Mediate Visually Evoked Retreat in Drosophila", "사이언스온"],
    ["Moonwalker Descending Neurons (MDN)",
     "Olfactory stimuli and moonwalker SEZ neurons can drive backward locomotion in Drosophila", "사이언스온"],
    ["Moonwalker Descending Neurons (MDN)",
     "TwoLumps Ascending Neurons Mediate Touch-Evoked Reversal of Walking Direction in Drosophila", "사이언스온"],
    ["Moonwalker Descending Neurons (MDN)",
     "Imaging neural activity in the ventral nerve cord of behaving adult Drosophila", "사이언스온"],
    ["Moonwalker Descending Neurons (MDN)",
     "Hunchback functions in the post-mitotic larval MDN to restrict axon outgrowth, synapse formation, and backward locomotion", "사이언스온"],

    # 7. Cancer cells optimize elasticity for efficient migration
    ["Cancer cells optimize elasticity for efficient migration", "Tunable mechanobiology of ferroptotic cancer cells using nanoencapsulation increases the efferocytosis efficiency", "데이터온"],
    ["Cancer cells optimize elasticity for efficient migration", "Cancer cells optimize elasticity for efficient migration", "사이언스온"],
    ["Cancer cells optimize elasticity for efficient migration", "Shifting the optimal stiffness for cell migration", "사이언스온"],
    ["Cancer cells optimize elasticity for efficient migration", "Matrix mechanical plasticity regulates cancer cell migration through confining microenvironments", "사이언스온"],
    ["Cancer cells optimize elasticity for efficient migration", "Substrate stiffness modulates lung cancer cell migration but not epithelial to mesenchymal transition", "사이언스온"],
    ["Cancer cells optimize elasticity for efficient migration", "Effect of Nuclear Stiffness on Cell Mechanics and Migration of Human Breast Cancer Cells", "사이언스온"],
    ["Cancer cells optimize elasticity for efficient migration", "Cell Migration and Breast Cancer Metastasis in Biomimetic Extracellular Matrices with Independently Tunable Stiffness", "사이언스온"],
    ["Cancer cells optimize elasticity for efficient migration", "Differential modulation of cell morphology, migration, and Neuropilin-1 expression in cancer and non-cancer cell lines by substrate stiffness", "사이언스온"],

    # 8. Cluster similarity spectrum integration of single-cell genomics data
    ["Cluster similarity spectrum integration of single-cell genomics data", "Spatiotemporal Analysis of Human Intestinal Development at Single Cell Resolution: Supplementary Data", "데이터온"],
    ["Cluster similarity spectrum integration of single-cell genomics data", "CSS: cluster similarity spectrum integration of single-cell genomics data", "사이언스온"],
    ["Cluster similarity spectrum integration of single-cell genomics data", "Evaluating single-cell cluster stability using the Jaccard similarity index", "사이언스온"],
    ["Cluster similarity spectrum integration of single-cell genomics data", "Comparison of clustering tools in R for medium-sized 10x Genomics single-cell RNA-sequencing data", "사이언스온"],
    ["Cluster similarity spectrum integration of single-cell genomics data", "Semi-supervised integration of single-cell transcriptomics data", "사이언스온"],
    ["Cluster similarity spectrum integration of single-cell genomics data", "Benchmarking atlas-level data integration in single-cell genomics", "사이언스온"],

    # 9. Tissue-specific Gene Regulatory Networks
    ["Tissue-specific Gene Regulatory Networks", "Lung gene regulatory network", "데이터온"],
    ["Tissue-specific Gene Regulatory Networks", "Tissue-specific gene regulatory networks inferred with GRNBoost2 (arboreto)", "데이터온"],
    ["Tissue-specific Gene Regulatory Networks", "Tissue-specific gene regulatory networks inferred with ANANSE 0.2.0", "데이터온"],
    ["Tissue-specific Gene Regulatory Networks", "Trans-eQTLs Can Be Used to Identify Tissue-Specific Gene Regulatory Networks", "사이언스온"],
    ["Tissue-specific Gene Regulatory Networks", "Transcription Factor Activity Mapping of a Tissue-Specific In Vivo Gene Regulatory Network", "사이언스온"],
    ["Tissue-specific Gene Regulatory Networks", "Tissue-specific regulatory network extractor (TS-REX): a database and software resource for the tissue and cell type-specific investigation of transcription factor-gene networks", "사이언스온"],

    # 10. A Multi-Type Birth-Death model for Bayesian inference of lineage-specific birth and death rates
    ["A Multi-Type Birth-Death model for Bayesian inference of lineage-specific birth and death rates", "Data from: Swapping birth and death: symmetries and transformations in phylodynamic models", "데이터온"],
    ["A Multi-Type Birth-Death model for Bayesian inference of lineage-specific birth and death rates", "A Multitype Birth–Death Model for Bayesian Inference of Lineage-Specific Birth and Death Rates", "사이언스온"],
    ["A Multi-Type Birth-Death model for Bayesian inference of lineage-specific birth and death rates", "NestedBD: Bayesian inference of phylogenetic trees from single-cell copy number profiles under a birth-death model", "사이언스온"],
    ["A Multi-Type Birth-Death model for Bayesian inference of lineage-specific birth and death rates", "The ClaDS rate-heterogeneous birth–death prior for full phylogenetic inference in BEAST2", "사이언스온"],
    ["A Multi-Type Birth-Death model for Bayesian inference of lineage-specific birth and death rates", "Locally adaptive Bayesian birth-death model successfully detects slow and rapid rate shifts", "사이언스온"],
    ["A Multi-Type Birth-Death model for Bayesian inference of lineage-specific birth and death rates", "Integrating fossil samples with heterogeneous diversification rates: a combined Multi-Type Fossilized Birth-Death model", "사이언스온"],
    ["A Multi-Type Birth-Death model for Bayesian inference of lineage-specific birth and death rates", "Improved multi-type birth-death phylodynamic inference in BEAST 2", "사이언스온"],
    ["A Multi-Type Birth-Death model for Bayesian inference of lineage-specific birth and death rates", "Fast and Accurate Maximum-Likelihood Estimation of Multi-Type Birth–Death Epidemiological Models from Phylogenetic Trees", "사이언스온"],

    # 11. India GDP
    ["India GDP", "GDP data", "데이터온"],
    ["India GDP", "Causal Relationship between Exports and Agricultural GDP in India", "사이언스온"],
    ["India GDP", "Software and services export, IT investment and GDP nexus in India", "사이언스온"],
    ["India GDP", "Causal Relationship between Capital Inflows and GDP: The Case of India (Causal Relationship between Capital Inflows and GDP: The Case of India)", "사이언스온"],
    ["India GDP", "On The Estimability of Gross National Product In India", "사이언스온"],
    ["India GDP", "Gross National Product", "사이언스온"],
    ["India GDP", "The Reliability of U.S. Gross National Product", "사이언스온"],

    # 12. Consumer Price Indices
    ["Consumer Price Indices", "Estimated Effect of the Budget on Consumer Price Indices and Retail Prices Index", "데이터온"],
    ["Consumer Price Indices", "Focus on Consumer Prices", "데이터온"],
    ["Consumer Price Indices", "Consumer Price indices", "사이언스온"],
    ["Consumer Price Indices", "European consumer price indices since 1870", "사이언스온"],
    ["Consumer Price Indices", "Web scraped data in consumer price indices", "사이언스온"],
    ["Consumer Price Indices", "Changes in retail energy prices and the consumer price index", "사이언스온"],
    ["Consumer Price Indices", "How can big data enhance the timeliness of official statistics? : The case of the U.S. consumer price index", "사이언스온"],
    ["Consumer Price Indices", "Assessing the effect of new data sources on the consumer price index: a deterministic approach to uncertainty and sensitivity", "사이언스온"],

    # 13. THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL
    ["THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL", "Mexican Wealth Distribution 1810-1910", "데이터온"],
    ["THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL", "지속 가능한 발전을 위한 브라질 경제체제의 전환: 세제개혁을 중심으로Transition of Brazil's Economic System for Sustainable Development: Focusing on Tax Reform", "사이언스온"],
    ["THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL", "THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL", "사이언스온"],
    ["THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL", "상속 · 증여가 가구의 순자산분포에 미친 효과 (The Effects of Inheritance and Gift on the Net Worth Distribution of Household)", "사이언스온"],
    ["THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL", "The Crucial Role of Social Welfare Criteria and Individual Heterogeneity for Optimal Inheritance Taxation", "사이언스온"],
    ["THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL", "On the Accumulation of Wealth: The Role of Inheritances | how do inheritances shape wealth inequality theory and evidence from Sweden", "사이언스온"],
    ["THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL", "The Institute's Conference on Poverty, Wealth and Income Distribution in Australia: Introduction", "사이언스온"],
    ["THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL", "Inheritance, Wealth Distribution, and Estate Taxation", "사이언스온"],
    ["THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL", "The Impact of Inheritance on the Distribution of Wealth: Evidence from China", "사이언스온"],
    ["THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL", "Inheritance and wealth inequality: Evidence from population registers", "사이언스온"],

    # 14. Changes in school enrollment in 1990-2011 (higher education)
    ["Changes in school enrollment in 1990-2011 (higher education)", "History of CPS Enrollment 1999-2014 Open Data", "데이터온"],
    ["Changes in school enrollment in 1990-2011 (higher education)", "Factors associated with college attendance of high-school seniors", "사이언스온"],
    ["Changes in school enrollment in 1990-2011 (higher education)", "The impact of the Bolsa Escola/Familia conditional cash transfer program on enrollment, dropout rates and grade promotion in Brazil", "사이언스온"],
    ["Changes in school enrollment in 1990-2011 (higher education)", "Expanding Dual Enrollment: Increasing Postsecondary Access for All?", "사이언스온"],
    ["Changes in school enrollment in 1990-2011 (higher education)", "Changes in school enrollment patterns in Israel: A comparison between two disadvantaged groups", "사이언스온"],
    ["Changes in school enrollment in 1990-2011 (higher education)", "Student Enrollment in World Languages: L'Égalité des Chances?", "사이언스온"],
    ["Changes in school enrollment in 1990-2011 (higher education)", "소득분포와 중등 및 고등교육기관에 대한 등록률 (Income Distribution and School Enrollment)", "사이언스온"],
    ["Changes in school enrollment in 1990-2011 (higher education)", "A School-Level Gravity Model of Student Migration Flows to Higher Education Institutions", "사이언스온"],

    # 15. Data SRL EdTech & Academic Achievement
    ["Data SRL EdTech & Academic Achievement", "School engagement, SRL and academic achievement", "데이터온"],
    ["Data SRL EdTech & Academic Achievement", "Using of reciprocal teaching to enhance academic achievement: a systematic literature review", "사이언스온"],
    ["Data SRL EdTech & Academic Achievement", "Predicting academic performance: a systematic literature review", "사이언스온"],
    ["Data SRL EdTech & Academic Achievement", "Systematic Literature Review: The Effect of Student Interaction on Academic Achievement in Online Learning", "사이언스온"],
    ["Data SRL EdTech & Academic Achievement", "자기조절 학습전략 훈련이 자기 주도적 학습능력과 학업성취도 및 학습태도에 미치는 영향", "사이언스온"],
    ["Data SRL EdTech & Academic Achievement", "Effects of Educational Technology on Students’ Academic Achievement in Agricultural Education: A Meta-analysis", "사이언스온"],
    ["Data SRL EdTech & Academic Achievement", "Augmented Reality as a Sustainable Technology to Improve Academic Achievement in Students with and without Special Educational Needs", "사이언스온"],
    ["Data SRL EdTech & Academic Achievement", "Using Innovations and Educational Technology Techniques to Deliver Educational Practicum and its effect on Increasing Academic Achievement among Pre-Service Teachers", "사이언스온"],

    # 16. Educational Resources from UC Berkeley RDM Librarian Training Program
    ["Educational Resources from UC Berkeley RDM Librarian Training Program", "EXPLORING THE OPEN EDUCATIONAL RESOURCES IN LIBRARIES", "데이터온"],
    ["Educational Resources from UC Berkeley RDM Librarian Training Program", "Research Data Management Training in Academic Libraries: A Scoping Review", "사이언스온"],
    ["Educational Resources from UC Berkeley RDM Librarian Training Program", "Developments in research data management in academic libraries: Towards an understanding of research data service maturity", "사이언스온"],
    ["Educational Resources from UC Berkeley RDM Librarian Training Program", "Modifying researchers’ data management practices : A behavioural framework for library practitioners", "사이언스온"],
    ["Educational Resources from UC Berkeley RDM Librarian Training Program", "Open Educational Resources", "사이언스온"],

    # 17. Population: Migration Patterns of Russian Academics
    ["Population: Migration Patterns of Russian Academics", "Understanding the Migration Patterns of Russian Academics through New Institutional Economics", "데이터온"],
    ["Population: Migration Patterns of Russian Academics", "Mapping Longitudinal Migration Patterns from Population-Scale Family Trees", "데이터온"],
    ["Population: Migration Patterns of Russian Academics", "러시아 이주의 현황과 특징 : 극동연방구에 대한 경험적 분석 (Migration Patterns in Russia : An Empirical Study in the Russian Far East)", "사이언스온"],
    ["Population: Migration Patterns of Russian Academics", "Intra-Russian educational migration of youth: the attractiveness of regions for pursuing higher education", "사이언스온"],
    ["Population: Migration Patterns of Russian Academics", "Bilateral flows and rates of international migration of scholars for 210 countries for the period 1998-2020", "사이언스온"],
    ["Population: Migration Patterns of Russian Academics", "On socialization, patriotism and trust: the migration of homeward-bound Russian academics", "사이언스온"],
    ["Population: Migration Patterns of Russian Academics", "Does the Socialization of Young Russian Academics Foster Migration?", "사이언스온"],
    ["Population: Migration Patterns of Russian Academics", "Russian brain drain: Myths v. reality", "사이언스온"],

    # 18. Census - Census Families
    ["Census - Census Families", "Census Families Profiles for Community Health Service Areas - 2016 Census", "데이터온"],
    ["Census - Census Families", "Canadian census families: Adjust or not", "사이언스온"],
    ["Census - Census Families", "인구주택 총조사 자료를 이용한 인구, 가구, 주택 특성과 빈집 현황 분석 (Analysis of the Effects of Population, Household, and Housing Characteristics on the Status of Empty Houses Using Population Housing Census Data)", "사이언스온"],
    ["Census - Census Families", "Using Census Data For Research On The Family in Canada", "사이언스온"],
    ["Census - Census Families", "Constructing Census Families and Classifying Households: “Relationship to Head of Family or Household” in the 1901 Census of Canada", "사이언스온"],
    ["Census - Census Families", "Measurement of Family and Household Composition in Census 2000: An Update", "사이언스온"],

    # 19. Mechanical design documentation for the trim-cut setup
    ["Mechanical design documentation for the trim-cut setup", "Mechanical design BLAZE pilot plant components", "데이터온"],
    ["Mechanical design documentation for the trim-cut setup", "High-speed trim-cut videos of laser flame cutting", "데이터온"],
    ["Mechanical design documentation for the trim-cut setup", "Trim-cut technique for analysis of melt flow dynamics in industrial laser cutting machine", "사이언스온"],
    ["Mechanical design documentation for the trim-cut setup", "Advanced trim-cut technique to visualize melt flow dynamics inside laser cutting kerfs", "사이언스온"],
    ["Mechanical design documentation for the trim-cut setup", "The Innovation of Using 3D Printing Technology in Mechanical and Manufacturing Engineering", "사이언스온"],
    ["Mechanical design documentation for the trim-cut setup", "Expert systems in mechanical and manufacturing engineering", "사이언스온"],
    ["Mechanical design documentation for the trim-cut setup", "Knowledge-based expert systems for mechanical and manufacturing engineering", "사이언스온"],

    # 20. 3D CAD Assembly test models
    ["3D CAD Assembly test models", "A set of CAD assembly test models to evaluate component interfaces using CAD assembly modules", "데이터온"],
    ["3D CAD Assembly test models", "A structured analysis of CAD assembly model interfaces for their enhanced computerized processing", "사이언스온"],
    ["3D CAD Assembly test models", "Shape distribution-based approach to comparing 3D CAD assembly models", "사이언스온"],
    ["3D CAD Assembly test models", "Research on 3D-CAD Oriented Assembly Sequence Modeling System", "사이언스온"],
    ["3D CAD Assembly test models", "User-assisted integrated method for controlling level of detail of large-scale B-rep assembly models", "사이언스온"],
    ["3D CAD Assembly test models", "Simplification of feature-based 3D CAD assembly data of ship and offshore equipment using quantitative evaluation metrics", "사이언스온"],

    # 21. KupferDigital mechanical testing datasets
    ["KupferDigital mechanical testing datasets", "KupferDigital mechanical testing datasets: Brinell hardness, Vickers hardness, and tensile tests", "데이터온"],
    ["KupferDigital mechanical testing datasets", "KupferDigital mechanical testing datasets: Stress relaxation and low-cycle fatigue (LCF) tests", "데이터온"],
    ["KupferDigital mechanical testing datasets", "KupferDigital: Ontology‐Based Digital Representation for the Copper Life Cycle", "사이언스온"],
    ["KupferDigital mechanical testing datasets", "Semantic Representation of Low‐Cycle-Fatigue Testing Data Using a Fatigue Test Ontology and ckan.kupferdigital Data Management System", "사이언스온"],
    ["KupferDigital mechanical testing datasets", "Mechanical testing dataset of cast copper alloys for the purpose of digitalization", "사이언스온"],
    ["KupferDigital mechanical testing datasets", "Mechanical Testing Methods of Micro Structures", "사이언스온"],
    ["KupferDigital mechanical testing datasets", "Automated mechanical testing", "사이언스온"],
    ["KupferDigital mechanical testing datasets", "Small-Scale Mechanical Testing", "사이언스온"],

    # 22. Efficient Design of Reversible Sequential Circuit
    ["Efficient Design of Reversible Sequential Circuit", "Efficient Design of Reversible Sequential Circuit", "사이언스온"],
    ["Efficient Design of Reversible Sequential Circuit", "Efficient Design Approach of Specific Sequential Circuits using Novel Reversible Gates", "사이언스온"],
    ["Efficient Design of Reversible Sequential Circuit", "Quantum Cost Optimization for Reversible Sequential Circuit", "사이언스온"],
    ["Efficient Design of Reversible Sequential Circuit", "Design of reversible sequential circuits optimizing quantum cost, delay, and garbage outputs", "사이언스온"],

    # 23. Data for Optimization on Electric Power Distribution Systems
    ["Data for Optimization on Electric Power Distribution Systems", "OnlineSupplement.xlsx", "데이터온"],
    ["Data for Optimization on Electric Power Distribution Systems", "Special issue on “Optimization in electric power distribution systems”", "사이언스온"],
    ["Data for Optimization on Electric Power Distribution Systems", "Optimal vegetation maintenance scheduling of overhead electric power distribution systems", "사이언스온"],
    ["Data for Optimization on Electric Power Distribution Systems", "Resiliency-based optimization of restoration policies for electric power distribution systems", "사이언스온"],
    ["Data for Optimization on Electric Power Distribution Systems", "Integrated parameter data flow in hybrid electric aircraft power management systems", "사이언스온"],
    ["Data for Optimization on Electric Power Distribution Systems", "Optimal Placement of Remote Controlled Switches in Electric Power Distribution Systems with a Meta-heuristic Approach", "사이언스온"],
    ["Data for Optimization on Electric Power Distribution Systems", "Energy Loss Reduction for Distribution Electric Power Systems with Renewable Power Sources, Reactive Power Compensators, and Electric Vehicle Charge Stations", "사이언스온"],
    ["Data for Optimization on Electric Power Distribution Systems", "Maintenance strategy selection in electric power distribution systems (No.15)", "사이언스온"],

    # 24. Overhead Comparison of Instrumentation Frameworks
    ["Overhead Comparison of Instrumentation Frameworks", "Data for: A Benchmark Engineering Methodology to Measure the Overhead of Application-Level Monitoring", "데이터온"],
    ["Overhead Comparison of Instrumentation Frameworks", "Contactless Phase Comparison Method for Overhead Transmission Lines", "사이언스온"],
    ["Overhead Comparison of Instrumentation Frameworks", "Cost and Performance Comparison of U.S. Overhead Sign Support Structures", "사이언스온"],
    ["Overhead Comparison of Instrumentation Frameworks", "A Comparison of Fast and Low Overhead Distributed Priority Locks", "사이언스온"],
    ["Overhead Comparison of Instrumentation Frameworks", "On-Line Temperature Estimation for Noisy Thermal Sensors Using a Smoothing Filter-Based Kalman Predictor", "사이언스온"],
    ["Overhead Comparison of Instrumentation Frameworks", "a domain-specific language for bytecode instrumentation", "사이언스온"],
    ["Overhead Comparison of Instrumentation Frameworks", "Performance Evaluation of Dynamic Binary Instrumentation Frameworks", "사이언스온"],
    ["Overhead Comparison of Instrumentation Frameworks", "DBIMAT: A Runtime Program Monitoring and Performance Analysis Tool Based on Dynamic Program Instrumentation Frameworks", "사이언스온"],
    ["Overhead Comparison of Instrumentation Frameworks", "An auto-routing multi-server architecture for high-education training on instrumentation and measurement", "사이언스온"],

    # 25. Co-design support methods and tools in the building design process
    ["Co-design support methods and tools in the building design process", "", "데이터온"],
    ["Co-design support methods and tools in the building design process", "Improving the communication of multifactorial cancer risk assessment results for different audiences: a co-design process", "사이언스온"],
    ["Co-design support methods and tools in the building design process", "Conceptual Architectural Design at Scale: A Case Study of Community Participation Using Crowdsourcing", "사이언스온"],
    ["Co-design support methods and tools in the building design process", "Co-design in the architectural process", "사이언스온"],
    ["Co-design support methods and tools in the building design process", "A Systematic Review of Architectural Design Collaboration in Immersive Virtual Environments", "사이언스온"],
    ["Co-design support methods and tools in the building design process", "Data processing, analysis, and evaluation methods for co-design of coreless filament-wound building systems", "사이언스온"],
    ["Co-design support methods and tools in the building design process", "REN+HOMES Positive Carbon Building Methodology in Co-Design with Residents", "사이언스온"],

    # 26. Multi-criteria optimization carbon dioxide through wood and bio-based construction materials
    ["Multi-criteria optimization carbon dioxide through wood and bio-based construction materials", "Multi-criteria optimization and seismic performance assessment of carbon FRP-based elastomeric isolator", "사이언스온"],
    ["Multi-criteria optimization carbon dioxide through wood and bio-based construction materials", "Multi-criteria screening of carbon dioxide utilization products combined with process optimization and evaluation", "사이언스온"],
    ["Multi-criteria optimization carbon dioxide through wood and bio-based construction materials", "Impact of agriculture intensification on forest degradation and tree carbon stock; promoting multi‐criteria optimization for restoration in Central India", "사이언스온"],
    ["Multi-criteria optimization carbon dioxide through wood and bio-based construction materials", "A REVIEW OF BIO-BASED MATERIALS AS REINFORCEMENT IN CONCRETE COMPOSITES: MECHANICAL, CARBON CAPTURE, AND SELF-HEALING PERFORMANCE", "사이언스온"],
    ["Multi-criteria optimization carbon dioxide through wood and bio-based construction materials", "HOME: Wood-Mycelium Composites for CO2-Neutral, Circular Interior Construction and Fittings", "사이언스온"],
    ["Multi-criteria optimization carbon dioxide through wood and bio-based construction materials", "Strawbale buildings as carbon sinks: influence of the design and construction process on carbon emissions", "사이언스온"],

    # 27. GEO Mountains Inventory of In Situ Observational Infrastructure v2.0
    ["GEO Mountains Inventory of In Situ Observational Infrastructure v2.0", "GEO Mountains Inventory of In Situ Observational Infrastructure v1.0", "데이터온"],
    ["GEO Mountains Inventory of In Situ Observational Infrastructure v2.0", "GEO Mountains General Inventory v1.0", "데이터온"],
    ["GEO Mountains Inventory of In Situ Observational Infrastructure v2.0", "Coverage of In Situ Climatological Observations in the World's Mountains", "사이언스온"],
    ["GEO Mountains Inventory of In Situ Observational Infrastructure v2.0", "Advancing Observational Infrastructure in the Arctic", "사이언스온"],
    ["GEO Mountains Inventory of In Situ Observational Infrastructure v2.0", "Environmental monitoring in Jiangsu Province: the model of innovation and practice (Jiang et al., 2004)", "사이언스온"],
    ["GEO Mountains Inventory of In Situ Observational Infrastructure v2.0", "Development of Networked Environmental Monitoring Data Management Platform (Zhang et al., 2005)", "사이언스온"],
    ["GEO Mountains Inventory of In Situ Observational Infrastructure v2.0", "Environmental Monitoring System for Base Station with Sensor Node Networks (허정인, 김환용, 2009)", "사이언스온"],
]

# %%
# mapping 정의
mapping = {
    "Hydrogen and dark oxygen drive microbial productivity in diverse groundwater ecosystems": "추천",
    "Codon Optimization, Expression in Escherichia coli , and Immunogenicity of Recombinant Chinese Sacbrood Virus (CSBV) Structural Proteins VP1, VP2, and VP3": "강추",
    "S239D/I332E 변이 항체 Fc와 FcγRIIIa 수용체의 결합 구조에 대한 전산학적 연구 (In Silico Structural Study on the Binding of Antibody IgG Fc-S239D/I332E variant and FcγRIIIa Receptor)": "추천",
    "Tumor-educated Tregs drive organ-specific metastasis in breast cancer by impairing NK cells in the lymph node niche": "추천",
    "Moonwalker Descending Neurons Mediate Visually Evoked Retreat in Drosophila": "강추",
    "CSS: cluster similarity spectrum integration of single-cell genomics data": "강추",
    "Trans-eQTLs Can Be Used to Identify Tissue-Specific Gene Regulatory Networks": "강추",
    "A Multitype Birth–Death Model for Bayesian Inference of Lineage-Specific Birth and Death Rates": "추천",
    "Causal Relationship between Capital Inflows and GDP: The Case of India (Causal Relationship between Capital Inflows and GDP: The Case of India)": "추천",
    "Consumer Price indices": "추천",
    "Census Families Profiles for Community Health Service Areas - 2016 Census": "추천",
    "Canadian census families: Adjust or not": "추천",
    "A set of CAD assembly test models to evaluate component interfaces using CAD assembly modulest": "추천",
    "Shape distribution-based approach to comparing 3D CAD assembly models": "추천",
    "Efficient Design of Reversible Sequential Circuit": "추천",
    "GEO Mountains Inventory of In Situ Observational Infrastructure v1.0": "추천",
}

# data 리스트를 순회하며 마지막 컬럼 값 수정
for i in range(len(data)):
    output_value = data[i][1]  # output 컬럼
    if output_value in mapping:
        data[i].append(mapping[output_value])
    else:
        data[i].append("참고")  # 기본값

# %%
df = pd.DataFrame(data, columns=["입력", "추천결과", "구분", "추천수준"])
df
# Out:
#                                                     입력  \
# 0    Relative abundances of archaeal amplicon seque...
# 1    Relative abundances of archaeal amplicon seque...
# 2    Relative abundances of archaeal amplicon seque...
# 3    Relative abundances of archaeal amplicon seque...
# 4    Relative abundances of archaeal amplicon seque...
# ..                                                 ...
# 187  GEO Mountains Inventory of In Situ Observation...
# 188  GEO Mountains Inventory of In Situ Observation...
# 189  GEO Mountains Inventory of In Situ Observation...
# 190  GEO Mountains Inventory of In Situ Observation...
# 191  GEO Mountains Inventory of In Situ Observation...
#
#                                                   추천결과     구분 추천수준
# 0    Nucleotide sequences of archaeal amplicon sequ...   데이터온   참고
# 1    From Recharge, to Groundwater, to Discharge Ar...  사이언스온   참고
# 2    Hydrogen and dark oxygen drive microbial produ...  사이언스온   추천
# ...

# %%
df["구분"] = df["구분"].replace({"데이터온": "dataset", "사이언스온": "paper"})
df
# Out:
#                                                     입력  \
# 0    Relative abundances of archaeal amplicon seque...
# 1    Relative abundances of archaeal amplicon seque...
# 2    Relative abundances of archaeal amplicon seque...
# 3    Relative abundances of archaeal amplicon seque...
# 4    Relative abundances of archaeal amplicon seque...
# ..                                                 ...
# 187  GEO Mountains Inventory of In Situ Observation...
# 188  GEO Mountains Inventory of In Situ Observation...
# 189  GEO Mountains Inventory of In Situ Observation...
# 190  GEO Mountains Inventory of In Situ Observation...
# 191  GEO Mountains Inventory of In Situ Observation...
#
#                                                   추천결과       구분 추천수준
# 0    Nucleotide sequences of archaeal amplicon sequ...  dataset   참고
# 1    From Recharge, to Groundwater, to Discharge Ar...    paper   참고
# 2    Hydrogen and dark oxygen drive microbial produ...    paper   추천
# ...

# %%
test_name = ["Relative abundances of archaeal amplicon sequence variants (ASV) from Canadian Prairie groundwater ecosystems",
             "Cluster similarity spectrum integration of single-cell genomics data",
             "Tissue-specific Gene Regulatory Networks",
             "Proteomic Profiling of Seminal Plasma Proteins in Varicocele Patients",
             "Supporting Information(Immunogenicity study of CSBV structural proteins)",
             "HADDOCK models of mutant protein complexes",
             "Tumor-Educated Immune Cells Promote Metastatic Growth",
             "Moonwalker Descending Neurons (MDN)",
             "Cancer cells optimize elasticity for efficient migration",
             "A Multi-Type Birth-Death model for Bayesian inference of lineage-specific birth and death rates",
             "Population: Migration Patterns of Russian Academics",
             "Census - Census Families",
             "India GDP",
             "Consumer Price Indices",
             "THE ROLE OF INHERITANCE AND TAXATION ON WEALTH AND INCOME DISTRIBUTION IN BRAZIL AND THE STATE OF RIO GRANDE DO SUL",
             "Changes in school enrollment in 1990-2011 (higher education)",
             "Data SRL EdTech & Academic Achievement",
             "Educational Resources from UC Berkeley RDM Librarian Training Program",
             "Mechanical design documentation for the trim-cut setup",
             "3D CAD Assembly test models",
             "KupferDigital mechanical testing datasets",
             "Efficient Design of Reversible Sequential Circuit",
             "Data for Optimization on Electric Power Distribution Systems",
             "Overhead Comparison of Instrumentation Frameworks",
             "Co-design support methods and tools in the building design process",
             "Multi-criteria optimization carbon dioxide through wood and bio-based construction materials",
             "GEO Mountains Inventory of In Situ Observational Infrastructure v2.0"
             ]

test_name = pd.DataFrame(test_name, columns=["test_name"])

# %%
id = pd.read_csv("/content/drive/MyDrive/BDA/Rec_Agent/test_input_id.csv")
id
# Out:
#                                   id
# 0   66dd38ee92a4be4030294ea13691fd1e
# 1   454f2a43934b2bbe821e141fb468805c
# 2   ab592ddaf3c42bebb99178d8791b4c00
# 3   dd29c711a63e5fe8875030b994c236f7
# 4   5dcb611434bb4edec75dd684b91b6be9
# 5   2541aa0a4e0952e4df4206ea2ee104c8
# 6   1e0b76806cd220d971845de760c12451
# 7   6905e9e839b57c698931afe6d1200ef6
# 8   ac72f4f9b7730b9032d0b58347cbe468
# 9   8061c93c2ec807e5868c8d6d303127de
# 10  0c5c461017ad493572b96f9d11fa9e1c
# 11  4453724b5d10913d7595ccf1526ad141
# 12  950bcada96c1a02236ccd1299e3bc3d4
# 13  33e8b6d95eedf4e611d778ba8827afa9
# 14  f403604f5ab8efe9cdd1a2658e5a984f
# 15  2324967d87a7fed6a66e854c57cf9ddf
# 16  0c1a90b072d3c9a92810538871c8274c
# 17  b40b77764c58d8b011a3eb2e580c3796
# 18  edac81b436b0824201f8973e4d6670e4
# 19  32fa506e6919310b23d6cb9565597d4e
# 20  1bdcd37c858cabcb6e0022167c2b4bf2
# 21  1ef8b00258aad43097b841447d830d4f
# 22  55c1e7a362d3f0892b6febb23565f515
# 23  0ab58f1867932fe4523fa4765f346fc7
# ...

# %%
id_name = pd. concat([id, test_name], axis=1)
id_name
# Out:
#                                   id  \
# 0   66dd38ee92a4be4030294ea13691fd1e
# 1   454f2a43934b2bbe821e141fb468805c
# 2   ab592ddaf3c42bebb99178d8791b4c00
# 3   dd29c711a63e5fe8875030b994c236f7
# 4   5dcb611434bb4edec75dd684b91b6be9
# 5   2541aa0a4e0952e4df4206ea2ee104c8
# 6   1e0b76806cd220d971845de760c12451
# 7   6905e9e839b57c698931afe6d1200ef6
# 8   ac72f4f9b7730b9032d0b58347cbe468
# 9   8061c93c2ec807e5868c8d6d303127de
# 10  0c5c461017ad493572b96f9d11fa9e1c
# 11  4453724b5d10913d7595ccf1526ad141
# 12  950bcada96c1a02236ccd1299e3bc3d4
# 13  33e8b6d95eedf4e611d778ba8827afa9
# 14  f403604f5ab8efe9cdd1a2658e5a984f
# 15  2324967d87a7fed6a66e854c57cf9ddf
# 16  0c1a90b072d3c9a92810538871c8274c
# 17  b40b77764c58d8b011a3eb2e580c3796
# 18  edac81b436b0824201f8973e4d6670e4
# 19  32fa506e6919310b23d6cb9565597d4e
# 20  1bdcd37c858cabcb6e0022167c2b4bf2
# 21  1ef8b00258aad43097b841447d830d4f
# 22  55c1e7a362d3f0892b6febb23565f515
# 23  0ab58f1867932fe4523fa4765f346fc7
# ...

# %%
merged_df = id_name.merge(df, left_on="test_name", right_on="입력", how="left")
merged_df
# Out:
#                                    id  \
# 0    66dd38ee92a4be4030294ea13691fd1e
# 1    66dd38ee92a4be4030294ea13691fd1e
# 2    66dd38ee92a4be4030294ea13691fd1e
# 3    66dd38ee92a4be4030294ea13691fd1e
# 4    66dd38ee92a4be4030294ea13691fd1e
# ..                                ...
# 176  d790111eaaa8cad3480674fcca0f2a5e
# 177  d790111eaaa8cad3480674fcca0f2a5e
# 178  d790111eaaa8cad3480674fcca0f2a5e
# 179  d790111eaaa8cad3480674fcca0f2a5e
# 180  d790111eaaa8cad3480674fcca0f2a5e
#
#                                              test_name  \
# 0    Relative abundances of archaeal amplicon seque...
# 1    Relative abundances of archaeal amplicon seque...
# 2    Relative abundances of archaeal amplicon seque...
# 3    Relative abundances of archaeal amplicon seque...
# 4    Relative abundances of archaeal amplicon seque...
# ..                                                 ...
# 176  GEO Mountains Inventory of In Situ Observation...
# ...

# %%
merged_df = merged_df.drop("test_name", axis=1)
merged_df = merged_df.rename(columns={"id": "입력id"})

# %%
merged_df
# Out:
#                                  입력id  \
# 0    66dd38ee92a4be4030294ea13691fd1e
# 1    66dd38ee92a4be4030294ea13691fd1e
# 2    66dd38ee92a4be4030294ea13691fd1e
# 3    66dd38ee92a4be4030294ea13691fd1e
# 4    66dd38ee92a4be4030294ea13691fd1e
# ..                                ...
# 176  d790111eaaa8cad3480674fcca0f2a5e
# 177  d790111eaaa8cad3480674fcca0f2a5e
# 178  d790111eaaa8cad3480674fcca0f2a5e
# 179  d790111eaaa8cad3480674fcca0f2a5e
# 180  d790111eaaa8cad3480674fcca0f2a5e
#
#                                                     입력  \
# 0    Relative abundances of archaeal amplicon seque...
# 1    Relative abundances of archaeal amplicon seque...
# 2    Relative abundances of archaeal amplicon seque...
# 3    Relative abundances of archaeal amplicon seque...
# 4    Relative abundances of archaeal amplicon seque...
# ..                                                 ...
# 176  GEO Mountains Inventory of In Situ Observation...
# ...

# %%
merged_df.to_csv("/content/drive/MyDrive/BDA/Rec_Agent/data/final_test_data.csv", index=False, encoding="utf-8-sig")
